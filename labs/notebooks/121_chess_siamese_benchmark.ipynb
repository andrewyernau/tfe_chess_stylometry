# %% [markdown]
# # 121 · Chess Siamese — TESTS (modelo 120)
#
# Notebook de verificación **post-entrenamiento** usando el mismo protocolo del `111`,
# pero cargando el modelo obtenido en `120`.

# %% [markdown]
# ## Objetivos de esta batería
#
# - Repetir la batería del `111` para poder contrastar manualmente ambos modelos.
# - Evaluar jugadores vistos (hold-out): Top-1/Top-3/Top-5, confusión, recall por jugador.
# - Revisar separabilidad del embedding por distancias.
# - Probar jugadores no vistos (open-set) desde `.zst` y medir similitud por ELO.
# - Entregar resúmenes descriptivos en porcentaje.

# %%
import io
import math
import random
import re
from dataclasses import dataclass
from pathlib import Path
from typing import Dict, List, Optional, Tuple

import chess
import chess.pgn
import chess.svg
import cv2
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import zstandard as zstd
from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix,
    top_k_accuracy_score,
)
from sklearn.neighbors import KNeighborsClassifier

SEED = 314159
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

plt.style.use("seaborn-v0_8")
sns.set_context("talk")

print(f"TensorFlow {tf.__version__}")
# Out:
# 2026-04-09 12:46:54.607807: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-04-09 12:46:54.715892: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8473] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-04-09 12:46:54.749738: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1471] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-04-09 12:46:54.922656: I tensorflow/core/platform/cpu_feature_guard.cc:211] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE3 SSE4.1 SSE4.2 AVX, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# TensorFlow 2.17.0

# %%
TRAINED_PLAYERS = []


@dataclass
class EvalConfig:
    event_name: str = "compressed_120"
    sequence_len: int = 15
    fullmove_start: int = 15
    fullmove_end: int = 60
    image_size: Tuple[int, int] = (192, 192)
    embedding_dim: int = 256
    validation_fraction: float = 0.2
    min_samples_per_player: int = 12
    infer_batch_size: int = 4

    unknown_players_to_test: int = 12
    unknown_games_per_player: int = 8
    unknown_candidate_pool: int = 200
    unknown_min_elo: int = 800
    unknown_max_elo: int = 2600
    ood_quantile: float = 0.95


CONFIG = EvalConfig()
PLY_LABELS = [f"ply{i:02d}" for i in range(1, CONFIG.sequence_len + 1)]


def detect_repo_root() -> Path:
    current = Path.cwd().resolve()
    for candidate in [current, *current.parents]:
        if (candidate / "labs").exists():
            return candidate
    raise RuntimeError("No se encontró raíz del repo (carpeta labs/).")


def first_existing(candidates: List[Path], description: str) -> Path:
    for candidate in candidates:
        if candidate.exists():
            return candidate
    joined = "\n".join(str(c) for c in candidates)
    raise RuntimeError(f"No se encontró {description}. Candidatos:\n{joined}")


def discover_event_players(*dir_pairs: Tuple[Path, Path]) -> List[str]:
    player_sets = []
    for board_dir, heat_dir in dir_pairs:
        if not board_dir.exists() or not heat_dir.exists():
            continue
        players = {
            d.name
            for d in board_dir.iterdir()
            if d.is_dir() and (heat_dir / d.name).is_dir()
        }
        if players:
            player_sets.append(players)

    if not player_sets:
        raise RuntimeError("No se pudieron inferir jugadores entrenados desde el evento.")

    common_players = set.intersection(*player_sets) if len(player_sets) > 1 else player_sets[0]
    out = sorted(common_players)
    if not out:
        raise RuntimeError("La intersección de jugadores TRAIN/HOLDOUT está vacía.")
    return out


REPO_ROOT = detect_repo_root()

EVENT_DIR = first_existing(
    [
        REPO_ROOT / "labs" / "notebooks" / "output" / "events" / CONFIG.event_name,
        Path("/workspace/code/labs/notebooks/output/events") / CONFIG.event_name,
        Path(r"D:\CODE\jupyter\labs\notebooks\output\events") / CONFIG.event_name,
    ],
    "directorio del evento 120",
)

TRAIN_BOARD_DIR = EVENT_DIR / "board_images"
TRAIN_HEAT_DIR = EVENT_DIR / "heatmap_images"
HOLDOUT_BOARD_DIR = EVENT_DIR / "holdout_board_images"
HOLDOUT_HEAT_DIR = EVENT_DIR / "holdout_heatmap_images"
PGN_TESTS_DIR = EVENT_DIR / "pgn_tests"

TRAINING_STATE_DIR = EVENT_DIR / "training_state"
CHECKPOINTS_DIR = TRAINING_STATE_DIR / "checkpoints"
BEST_WEIGHTS_PATH = CHECKPOINTS_DIR / "metric_trainer_best.weights.h5"
LAST_WEIGHTS_PATH = CHECKPOINTS_DIR / "metric_trainer_last.weights.h5"
HISTORY_CSV_PATH = TRAINING_STATE_DIR / "history.csv"

ZST_PLAYERS_DIR = first_existing(
    [
        Path("/pgn_data/players"),
        Path(r"D:\pgn_output\players"),
        Path("/workspace/pgn_output/players"),
    ],
    "directorio de jugadores .zst",
)

assert TRAIN_BOARD_DIR.exists(), f"No existe {TRAIN_BOARD_DIR}"
assert HOLDOUT_BOARD_DIR.exists(), f"No existe {HOLDOUT_BOARD_DIR}"

TRAINED_PLAYERS = discover_event_players(
    (TRAIN_BOARD_DIR, TRAIN_HEAT_DIR),
    (HOLDOUT_BOARD_DIR, HOLDOUT_HEAT_DIR),
)

print(f"Repo: {REPO_ROOT}")
print(f"Evento: {EVENT_DIR}")
print(f"ZST dir: {ZST_PLAYERS_DIR}")
print(f"Jugadores entrenados inferidos ({len(TRAINED_PLAYERS)}): {TRAINED_PLAYERS}")
# Out:
# Repo: /workspace/code
# Evento: /workspace/code/labs/notebooks/output/events/compressed_120
# ZST dir: /pgn_data/players
# Jugadores entrenados inferidos (10): ['Arsibbalt-1991', 'Edssoto', 'Migrant-is', 'RRusso', 'V2ethereum', 'edulol', 'giliazov', 'sabino31', 'shanis34', 'ujjawal305']

# %% [markdown]
# ## 1) Carga de checkpoint del modelo (sin re-entrenar)

# %%
def build_embedding_model(
    seq_len: int, image_size: Tuple[int, int], embedding_dim: int
) -> tf.keras.Model:
    h, w = image_size

    board_input = tf.keras.layers.Input(
        shape=(seq_len, h, w, 3), name="board_sequence"
    )
    heat_input = tf.keras.layers.Input(
        shape=(seq_len, h, w, 1), name="heat_sequence"
    )

    base_cnn = tf.keras.applications.ResNet50(
        include_top=False,
        weights=None,  # evita descargas; el checkpoint local repone todos los pesos
        pooling="avg",
        input_shape=(h, w, 3),
    )
    base_cnn.trainable = False

    board_pre = tf.keras.layers.TimeDistributed(
        tf.keras.layers.Lambda(
            lambda x: tf.keras.applications.resnet50.preprocess_input(x * 255.0)
        ),
        name="board_preprocess",
    )(board_input)
    board_features = tf.keras.layers.TimeDistributed(
        base_cnn, name="board_backbone"
    )(board_pre)
    board_features = tf.keras.layers.TimeDistributed(
        tf.keras.layers.Dense(512, activation="gelu"), name="board_dense"
    )(board_features)

    heat_encoder = tf.keras.Sequential(
        [
            tf.keras.layers.Conv2D(32, 3, padding="same", activation="relu"),
            tf.keras.layers.MaxPooling2D(2),
            tf.keras.layers.Conv2D(64, 3, padding="same", activation="relu"),
            tf.keras.layers.MaxPooling2D(2),
            tf.keras.layers.Conv2D(128, 3, padding="same", activation="relu"),
            tf.keras.layers.GlobalAveragePooling2D(),
            tf.keras.layers.Dense(256, activation="gelu"),
        ],
        name="heat_encoder",
    )
    heat_features = tf.keras.layers.TimeDistributed(
        heat_encoder, name="heat_backbone"
    )(heat_input)

    fused = tf.keras.layers.Concatenate(name="fuse_modalities")(
        [board_features, heat_features]
    )
    fused = tf.keras.layers.LayerNormalization(name="fuse_norm")(fused)
    fused = tf.keras.layers.TimeDistributed(
        tf.keras.layers.Dense(512, activation="gelu"), name="fuse_dense"
    )(fused)

    temporal = tf.keras.layers.Bidirectional(
        tf.keras.layers.GRU(
            256,
            return_sequences=True,
            dropout=0.20,
            reset_after=False,
        ),
        name="temporal_gru",
    )(fused)
    pooled = tf.keras.layers.GlobalAveragePooling1D(name="temporal_pool")(temporal)

    x = tf.keras.layers.Dense(512, activation="gelu")(pooled)
    x = tf.keras.layers.Dropout(0.3)(x)
    x = tf.keras.layers.Dense(embedding_dim, activation=None, dtype="float32")(x)
    embedding = tf.keras.layers.Lambda(
        lambda t: tf.math.l2_normalize(t, axis=1), name="embedding_l2"
    )(x)

    return tf.keras.Model(
        inputs=[board_input, heat_input],
        outputs=embedding,
        name="stylometry_embedding_104",
    )


class MetricTrainer(tf.keras.Model):
    def __init__(
        self,
        embedding_model: tf.keras.Model,
        num_classes: int,
        margin: float = 0.06,
        ce_weight: float = 0.20,
    ):
        super().__init__()
        self.embedding_model = embedding_model
        self.classifier = tf.keras.layers.Dense(
            num_classes,
            use_bias=False,
            dtype="float32",
            name="classifier",
        )
        self.margin = float(margin)
        self.ce_weight = float(ce_weight)

    def call(self, inputs, training=False):
        emb = self.embedding_model(inputs, training=training)
        logits = self.classifier(emb)
        return emb, logits


def pick_checkpoint_path() -> Path:
    candidates = [
        BEST_WEIGHTS_PATH,
        LAST_WEIGHTS_PATH,
        *sorted(CHECKPOINTS_DIR.glob("*.weights.h5")),
        *sorted(TRAINING_STATE_DIR.glob("*.weights.h5")),
    ]
    for path in candidates:
        if path.exists():
            return path
    raise RuntimeError("No se encontró checkpoint de pesos (.weights.h5).")


CHECKPOINT_PATH = pick_checkpoint_path()

embedding_model = build_embedding_model(
    seq_len=CONFIG.sequence_len,
    image_size=CONFIG.image_size,
    embedding_dim=CONFIG.embedding_dim,
)
trainer = MetricTrainer(
    embedding_model=embedding_model,
    num_classes=len(TRAINED_PLAYERS),
)

dummy_inputs = {
    "board_sequence": np.zeros(
        (1, CONFIG.sequence_len, CONFIG.image_size[0], CONFIG.image_size[1], 3),
        dtype=np.float32,
    ),
    "heat_sequence": np.zeros(
        (1, CONFIG.sequence_len, CONFIG.image_size[0], CONFIG.image_size[1], 1),
        dtype=np.float32,
    ),
}
_ = trainer(dummy_inputs, training=False)
trainer.load_weights(str(CHECKPOINT_PATH))

embedding_model = trainer.embedding_model
print(f"Pesos cargados: {CHECKPOINT_PATH}")
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1775738819.075026     157 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:07:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1775738819.533529     157 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:07:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1775738819.533617     157 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:07:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1775738819.537539     157 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:07:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1775738819.537619     157 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:07:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1775738819.537661     157 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:07:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1775738819.796851     157 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:07:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1775738819.796939     157 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:07:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-04-09 12:46:59.796950: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2112] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# I0000 00:00:1775738819.797026     157 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:07:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-04-09 12:46:59.797477: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10859 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 5080, pci bus id: 0000:07:00.0, compute capability: 12.0
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# 2026-04-09 12:47:03.244387: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 91002
# W0000 00:00:1775738823.445587     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738823.466841     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738823.468664     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738823.491259     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738823.491879     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738823.492695     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738823.606960     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738823.652012     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738823.652680     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738823.654234     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738823.680306     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# W0000 00:00:1775738824.076822     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.077305     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.079016     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.079321     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.080936     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.083577     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.085505     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.085905     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.086307     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.128006     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.128420     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.183188     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.183840     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.188560     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.192389     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.192925     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.193957     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.194468     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824
157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.576269     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.576922     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.577246     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.577545     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.578072     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.578642     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.579128     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.589420     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.589581     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.589871     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.590285     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.590505     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.590706     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.591093     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.591671     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.592159     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.592826     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.593397     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.593911     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.594388     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.595023     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.595602     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.605056     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.605537     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.606022     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.606554     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.606967     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.607509     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.608014     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.608326     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.608626     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.609080     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.609445     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.609776     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.610151     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.610529     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.611040     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.632226     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.632489     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# ...
# W0000 00:00:1775738824.735557     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.736048     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.736546     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.738034     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.738796     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.739288     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.739739     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.740327     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.741569     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# W0000 00:00:1775738824.909706     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.909971     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.910190     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.910457     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.910760     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.911372     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.912077     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.912654     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.913369     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.914126     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.914858     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.926854     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.932773     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.933136     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.933639     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.934010     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.934427     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.935127     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.935549     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.936070     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.936790     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.937185     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.937631     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.938031     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.938621     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.939147     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.939730     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.940534     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.943311     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.945133     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.962159     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.962470     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.962793     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.963264     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.963580     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.963933     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.964311     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.964660     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.965045     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.965512     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.966083     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.966666     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.967082     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.967565     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.968260     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.969148     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.969750     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.981391     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.992889     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.993202     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.993504     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.993830     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.994184     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.995047     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.995847     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.996400     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.997069     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.997839     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738824.998580     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738825.000455     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738825.005227     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738825.005565     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738825.005895     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738825.006278     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738825.006646     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738825.007356     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738825.007753     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738825.008310     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738825.009016     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738825.009408     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738825.010080     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738825.010659     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738825.011246     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738825.011808     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738825.012475     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738825.013353     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738825.015348     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738825.016626     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738825.032330     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738825.032665     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738825.033148     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738825.033584     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738825.033886     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738825.034338     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738825.034740     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738825.035110     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738825.035478     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738825.035930     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738825.036421     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738825.036965     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738825.037386     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738825.037911     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738825.038804     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738825.039543     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738825.040292     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775738825.052013     157 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# Pesos cargados: /workspace/code/labs/notebooks/output/events/compressed_120/training_state/checkpoints/metric_trainer_best.weights.h5

# %% [markdown]
# ## 2) Utilidades de muestras, embeddings y ELO

# %%
@dataclass(frozen=True)
class GameSample:
    player: str
    game_id: str
    board_paths: Tuple[str, ...]
    heat_paths: Tuple[str, ...]


def _norm_player(name: str) -> str:
    return name.strip().lower().replace(" ", "_")


def discover_game_samples(
    board_dir: Path,
    heat_dir: Path,
    labels: List[str],
    players_whitelist: Optional[List[str]] = None,
    min_samples: int = 4,
) -> Tuple[Dict[str, List[GameSample]], pd.DataFrame]:
    whitelist = (
        {_norm_player(p) for p in players_whitelist}
        if players_whitelist
        else None
    )

    samples_by_player: Dict[str, List[GameSample]] = {}
    if not board_dir.exists():
        raise RuntimeError(f"No existe {board_dir}")

    player_dirs = sorted(d for d in board_dir.iterdir() if d.is_dir())
    first_label = labels[0]

    for player_dir in player_dirs:
        player = player_dir.name
        if whitelist and _norm_player(player) not in whitelist:
            continue

        heat_player_dir = heat_dir / player
        if not heat_player_dir.exists():
            continue

        game_ids = sorted(
            {
                path.stem.split("_")[1]
                for path in player_dir.glob(f"game_*_{first_label}.png")
            }
        )

        player_samples: List[GameSample] = []
        for game_id in game_ids:
            board_paths: List[str] = []
            heat_paths: List[str] = []
            valid = True

            for label in labels:
                bp = player_dir / f"game_{game_id}_{label}.png"
                hp = heat_player_dir / f"game_{game_id}_{label}.png"
                if not bp.exists() or not hp.exists():
                    valid = False
                    break
                board_paths.append(str(bp))
                heat_paths.append(str(hp))

            if not valid:
                continue

            player_samples.append(
                GameSample(
                    player=player,
                    game_id=game_id,
                    board_paths=tuple(board_paths),
                    heat_paths=tuple(heat_paths),
                )
            )

        if len(player_samples) >= min_samples:
            samples_by_player[player] = player_samples

    if not samples_by_player:
        raise RuntimeError("No se encontraron muestras válidas.")

    rows = [{"player": p, "games": len(s)} for p, s in samples_by_player.items()]
    stats_df = (
        pd.DataFrame(rows)
        .sort_values("games", ascending=False)
        .reset_index(drop=True)
    )
    return samples_by_player, stats_df


def split_samples_by_player(
    samples_by_player: Dict[str, List[GameSample]],
    val_fraction: float,
    seed: int,
) -> Tuple[
    Dict[str, List[GameSample]],
    Dict[str, List[GameSample]],
    List[GameSample],
    List[GameSample],
]:
    rng = random.Random(seed)
    train_dict: Dict[str, List[GameSample]] = {}
    val_dict: Dict[str, List[GameSample]] = {}

    for player, samples in samples_by_player.items():
        shuffled = samples.copy()
        rng.shuffle(shuffled)

        val_count = max(1, int(len(shuffled) * val_fraction))
        while val_count > 0 and (len(shuffled) - val_count) < 2:
            val_count -= 1

        train_samples = shuffled[val_count:]
        val_samples = shuffled[:val_count] if val_count > 0 else []

        if len(train_samples) < 2:
            continue

        train_dict[player] = train_samples
        val_dict[player] = val_samples

    train_flat = [s for per_player in train_dict.values() for s in per_player]
    val_flat = [s for per_player in val_dict.values() for s in per_player]
    return train_dict, val_dict, train_flat, val_flat


def load_sequence_np(
    sample: GameSample,
    image_size: Tuple[int, int],
) -> Tuple[np.ndarray, np.ndarray]:
    h, w = image_size
    boards: List[np.ndarray] = []
    heats: List[np.ndarray] = []

    for bp, hp in zip(sample.board_paths, sample.heat_paths):
        bgr = cv2.imread(bp, cv2.IMREAD_COLOR)
        if bgr is None:
            raise RuntimeError(f"No se pudo leer imagen: {bp}")
        rgb = cv2.cvtColor(bgr, cv2.COLOR_BGR2RGB)
        rgb = cv2.resize(rgb, (w, h), interpolation=cv2.INTER_AREA)
        boards.append(rgb.astype(np.float32) / 255.0)

        heat = cv2.imread(hp, cv2.IMREAD_GRAYSCALE)
        if heat is None:
            raise RuntimeError(f"No se pudo leer heatmap: {hp}")
        heat = cv2.resize(heat, (w, h), interpolation=cv2.INTER_AREA)
        heats.append((heat.astype(np.float32) / 255.0)[..., None])

    return np.stack(boards), np.stack(heats)


def embed_samples_streaming(
    samples: List[GameSample],
    player_to_label: Dict[str, int],
    image_size: Tuple[int, int],
    batch_size: int = 4,
    tag: str = "SAMPLES",
) -> Tuple[np.ndarray, np.ndarray, List[str]]:
    if not samples:
        raise RuntimeError(f"No hay muestras para {tag}.")

    emb_chunks: List[np.ndarray] = []
    label_chunks: List[np.ndarray] = []
    players: List[str] = []

    total = len(samples)
    for start in range(0, total, batch_size):
        batch = samples[start : start + batch_size]

        boards = []
        heats = []
        labels = []
        for sample in batch:
            board_seq, heat_seq = load_sequence_np(sample, image_size)
            boards.append(board_seq)
            heats.append(heat_seq)
            labels.append(player_to_label[sample.player])
            players.append(sample.player)

        boards_np = np.stack(boards).astype(np.float32)
        heats_np = np.stack(heats).astype(np.float32)
        labels_np = np.array(labels, dtype=np.int32)

        emb_batch = embedding_model.predict(
            {"board_sequence": boards_np, "heat_sequence": heats_np},
            batch_size=len(batch),
            verbose=0,
        )
        emb_chunks.append(emb_batch.astype(np.float32))
        label_chunks.append(labels_np)

        processed = min(start + batch_size, total)
        print(f"{tag}: {processed}/{total}")

    embeddings = np.vstack(emb_chunks)
    labels = np.concatenate(label_chunks)
    return embeddings, labels, players


def find_zst_path(player_name: str) -> Optional[Path]:
    prefix = player_name[:2].lower()
    candidate = ZST_PLAYERS_DIR / prefix / f"{player_name}.pgn.zst"
    if candidate.exists():
        return candidate

    prefix_dir = ZST_PLAYERS_DIR / prefix
    if not prefix_dir.exists():
        return None

    target = f"{player_name.lower()}.pgn.zst"
    for file_path in prefix_dir.iterdir():
        if file_path.name.lower() == target:
            return file_path
    return None


def extract_elo_from_zst(zst_path: Path, max_bytes: int = 120_000) -> Optional[int]:
    try:
        dctx = zstd.ZstdDecompressor()
        with open(zst_path, "rb") as f:
            reader = dctx.stream_reader(f)
            text = reader.read(max_bytes).decode("utf-8", errors="replace")

        values: List[int] = []
        for line in text.splitlines():
            line = line.strip()
            if line.startswith("[WhiteElo") or line.startswith("[BlackElo"):
                try:
                    elo = int(line.split('"')[1])
                except (IndexError, ValueError):
                    continue
                if 400 <= elo <= 3500:
                    values.append(elo)

        if values:
            return int(np.median(values))
    except Exception:
        return None
    return None

# %%
def board_to_rgb_array(board: chess.Board, size: int = 400) -> np.ndarray:
    try:
        import cairosvg
    except ImportError as exc:
        raise ImportError("Falta cairosvg. Instala: pip install cairosvg") from exc

    svg_data = chess.svg.board(board=board, size=size, coordinates=False)
    png_data = cairosvg.svg2png(bytestring=svg_data.encode("utf-8"))
    png_array = np.frombuffer(png_data, dtype=np.uint8)
    bgr = cv2.imdecode(png_array, cv2.IMREAD_COLOR)
    rgb = cv2.cvtColor(bgr, cv2.COLOR_BGR2RGB)
    return rgb


def _norm_header_name(name: str) -> str:
    return name.strip().lower().replace(" ", "_")


def resolve_player_side(game: chess.pgn.Game, player_name: str) -> Optional[str]:
    white = _norm_header_name(game.headers.get("White", ""))
    black = _norm_header_name(game.headers.get("Black", ""))
    target = _norm_header_name(player_name)
    if white == target:
        return "white"
    if black == target:
        return "black"
    return None


def normalize_board_for_player(board: chess.Board, player_color: bool) -> chess.Board:
    return board if player_color == chess.WHITE else board.mirror()


CLOCK_RE = re.compile(r"\[%clk\s+([0-9:]+)\]")


def _clock_to_seconds(clock_text: str) -> Optional[int]:
    try:
        parts = [int(x) for x in clock_text.split(":")]
    except ValueError:
        return None
    if len(parts) == 3:
        h, m, s = parts
        return h * 3600 + m * 60 + s
    if len(parts) == 2:
        m, s = parts
        return m * 60 + s
    return None


def extract_decision_seconds_by_halfmove(game: chess.pgn.Game) -> Dict[int, Dict[str, float]]:
    decision_map: Dict[int, Dict[str, float]] = {}
    board = game.board()
    prev_clock = {"white": None, "black": None}
    halfmove = 0

    node = game
    while node.variations:
        node = node.variations[0]
        halfmove += 1
        board.push(node.move)

        mover = "white" if board.turn == chess.BLACK else "black"
        comment = node.comment or ""
        match = CLOCK_RE.search(comment)
        if not match:
            continue

        current_clock = _clock_to_seconds(match.group(1))
        if current_clock is None:
            continue

        previous = prev_clock[mover]
        if previous is None:
            delta = 0.0
        else:
            delta = float(max(0, previous - current_clock))

        decision_map[halfmove] = {"color": mover, "seconds": delta}
        prev_clock[mover] = current_clock

    return decision_map


def select_player_halfmoves(
    total_halfmoves: int,
    player_color: bool,
    fullmove_start: int,
    fullmove_end: int,
) -> List[int]:
    start = max(1, fullmove_start)
    end = max(start, fullmove_end)
    selected: List[int] = []

    for fullmove in range(start, end + 1):
        hm = 2 * fullmove - 1 if player_color == chess.WHITE else 2 * fullmove
        if hm <= total_halfmoves:
            selected.append(hm)
    return selected


def build_player_move_heatmap(
    move: chess.Move,
    decision_seconds: float,
    output_size: int,
    mirror_for_black: bool,
) -> np.ndarray:
    heat = np.zeros((8, 8), dtype=np.float32)

    to_sq = move.to_square
    row = 7 - chess.square_rank(to_sq)
    col = chess.square_file(to_sq)

    weight = max(0.0, float(math.log1p(max(0.0, decision_seconds))))
    if weight <= 0:
        weight = 0.5
    heat[row, col] = weight

    heat = cv2.GaussianBlur(heat, (0, 0), sigmaX=1.2, sigmaY=1.2)
    heat -= heat.min()
    maxv = float(heat.max())
    if maxv > 0:
        heat /= maxv
    heat = (heat * 255.0).astype(np.uint8)

    if mirror_for_black:
        heat = np.flipud(np.fliplr(heat))

    heat = cv2.resize(heat, (output_size, output_size), interpolation=cv2.INTER_CUBIC)
    return heat


def build_single_game_tensor(
    game: chess.pgn.Game,
    side: str,
    sequence_len: int,
    fullmove_start: int,
    fullmove_end: int,
    image_size: Tuple[int, int],
) -> Tuple[np.ndarray, np.ndarray]:
    side = side.lower().strip()
    if side not in {"white", "black"}:
        raise ValueError("side debe ser 'white' o 'black'.")

    player_color = chess.WHITE if side == "white" else chess.BLACK
    moves = list(game.mainline_moves())
    selected_halfmoves = select_player_halfmoves(
        total_halfmoves=len(moves),
        player_color=player_color,
        fullmove_start=fullmove_start,
        fullmove_end=fullmove_end,
    )
    if len(selected_halfmoves) < sequence_len:
        raise RuntimeError("La partida no tiene suficientes jugadas para esta configuración.")

    selected_halfmoves = selected_halfmoves[:sequence_len]
    decision_map = extract_decision_seconds_by_halfmove(game)

    board = game.board()
    board_states: Dict[int, chess.Board] = {}
    for hm, move in enumerate(moves, start=1):
        board.push(move)
        if hm in selected_halfmoves:
            board_states[hm] = board.copy()
        if len(board_states) == len(selected_halfmoves):
            break

    h, w = image_size
    boards = np.zeros((1, sequence_len, h, w, 3), dtype=np.float32)
    heats = np.zeros((1, sequence_len, h, w, 1), dtype=np.float32)

    expected_color_name = "white" if player_color == chess.WHITE else "black"
    for idx, hm in enumerate(selected_halfmoves):
        state = normalize_board_for_player(board_states[hm], player_color)
        rgb = board_to_rgb_array(state, size=400)
        rgb = cv2.resize(rgb, (w, h), interpolation=cv2.INTER_AREA)
        boards[0, idx] = rgb.astype(np.float32) / 255.0

        move = moves[hm - 1]
        info = decision_map.get(hm, {})
        seconds = (
            float(info.get("seconds", 0.0))
            if info.get("color") == expected_color_name
            else 0.0
        )
        heat = build_player_move_heatmap(
            move=move,
            decision_seconds=seconds,
            output_size=h,
            mirror_for_black=(player_color == chess.BLACK),
        )
        heats[0, idx, :, :, 0] = heat.astype(np.float32) / 255.0

    return boards, heats


def read_player_games_from_zst(
    zst_path: Path,
    player_name: str,
    max_games: int,
) -> List[Tuple[int, chess.pgn.Game, str]]:
    dctx = zstd.ZstdDecompressor()
    records: List[Tuple[int, chess.pgn.Game, str]] = []
    game_counter = 0

    with open(zst_path, "rb") as f:
        with dctx.stream_reader(f) as reader:
            text_reader = io.TextIOWrapper(reader, encoding="utf-8", errors="replace")
            current_lines: List[str] = []

            for line in text_reader:
                if line.startswith("[Event ") and current_lines:
                    game_counter += 1
                    game_text = "".join(current_lines)
                    game = chess.pgn.read_game(io.StringIO(game_text))
                    if game is not None:
                        side = resolve_player_side(game, player_name)
                        if side is not None:
                            records.append((game_counter, game, side))
                            if len(records) >= max_games:
                                break
                    current_lines = [line]
                else:
                    current_lines.append(line)

            if len(records) < max_games and current_lines:
                game_counter += 1
                game_text = "".join(current_lines)
                game = chess.pgn.read_game(io.StringIO(game_text))
                if game is not None:
                    side = resolve_player_side(game, player_name)
                    if side is not None:
                        records.append((game_counter, game, side))

    return records[:max_games]

# %% [markdown]
# ## 3) Reconstrucción TRAIN/HOLDOUT y centroides

# %%
SELECTED_PLAYERS = TRAINED_PLAYERS.copy()

rows = []
for player in SELECTED_PLAYERS:
    zst_path = find_zst_path(player)
    elo = extract_elo_from_zst(zst_path) if zst_path else None
    rows.append(
        {
            "player": player,
            "zst_path": str(zst_path) if zst_path else None,
            "elo": elo,
        }
    )

selected_players_df = pd.DataFrame(rows)
PLAYER_ELO = {
    row["player"]: float(row["elo"]) if pd.notna(row["elo"]) else np.nan
    for _, row in selected_players_df.iterrows()
}

train_samples_by_player, train_stats_df = discover_game_samples(
    board_dir=TRAIN_BOARD_DIR,
    heat_dir=TRAIN_HEAT_DIR,
    labels=PLY_LABELS,
    players_whitelist=SELECTED_PLAYERS,
    min_samples=CONFIG.min_samples_per_player,
)
holdout_samples_by_player, holdout_stats_df = discover_game_samples(
    board_dir=HOLDOUT_BOARD_DIR,
    heat_dir=HOLDOUT_HEAT_DIR,
    labels=PLY_LABELS,
    players_whitelist=SELECTED_PLAYERS,
    min_samples=1,
)

train_by_player, val_by_player, TRAIN_SAMPLES, VAL_SAMPLES = split_samples_by_player(
    samples_by_player=train_samples_by_player,
    val_fraction=CONFIG.validation_fraction,
    seed=SEED,
)
HOLDOUT_SAMPLES = [s for per_player in holdout_samples_by_player.values() for s in per_player]

PLAYER_TO_LABEL = {p: i for i, p in enumerate(sorted(train_by_player.keys()))}
LABEL_TO_PLAYER = {i: p for p, i in PLAYER_TO_LABEL.items()}

print(f"Jugadores válidos TRAIN: {len(train_by_player)}")
print(f"Muestras TRAIN: {len(TRAIN_SAMPLES)}")
print(f"Muestras HOLDOUT: {len(HOLDOUT_SAMPLES)}")
display(selected_players_df[["player", "elo"]].sort_values("elo"))
display(train_stats_df)
display(holdout_stats_df)

train_embeddings, train_labels, train_players = embed_samples_streaming(
    TRAIN_SAMPLES,
    PLAYER_TO_LABEL,
    CONFIG.image_size,
    batch_size=CONFIG.infer_batch_size,
    tag="TRAIN EMB",
)
hold_embeddings, hold_labels, hold_players = embed_samples_streaming(
    HOLDOUT_SAMPLES,
    PLAYER_TO_LABEL,
    CONFIG.image_size,
    batch_size=CONFIG.infer_batch_size,
    tag="HOLDOUT EMB",
)

num_classes = len(PLAYER_TO_LABEL)
centroid_players = [LABEL_TO_PLAYER[i] for i in range(num_classes)]

centroids = []
for class_idx in range(num_classes):
    class_emb = train_embeddings[train_labels == class_idx]
    if class_emb.size == 0:
        raise RuntimeError(f"Sin embeddings TRAIN para clase {class_idx}.")
    centroids.append(class_emb.mean(axis=0))
centroid_matrix = np.vstack(centroids)

centroid_dists = np.linalg.norm(
    hold_embeddings[:, None, :] - centroid_matrix[None, :, :],
    axis=2,
)
centroid_scores = -centroid_dists
centroid_pred = np.argmin(centroid_dists, axis=1)
print("Centroides listos.")
# Out:
# Jugadores válidos TRAIN: 10
# Muestras TRAIN: 1440
# Muestras HOLDOUT: 400
#            player   elo
# 7        sabino31   755
# 9      ujjawal305   941
# 0  Arsibbalt-1991  1197
# 2      Migrant-is  1229
# 5          edulol  1460
# 8        shanis34  1653
# 4      V2ethereum  1889
# 3          RRusso  1899
# 6        giliazov  2006
# 1         Edssoto  2280
#            player  games
# 0  Arsibbalt-1991    180
# 1         Edssoto    180
# 2      Migrant-is    180
# 3          RRusso    180
# 4      V2ethereum    180
# 5          edulol    180
# 6        giliazov    180
# 7        sabino31    180
# 8        shanis34    180
# 9      ujjawal305    180
#            player  games
# 0  Arsibbalt-1991     40
# 1         Edssoto     40
# 2      Migrant-is     40
# 3          RRusso     40
# 4      V2ethereum     40
# 5          edulol     40
# 6        giliazov     40
# 7        sabino31     40
# 8        shanis34     40
# 9      ujjawal305     40
# W0000 00:00:1775739012.889874     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739012.890679     238 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739012.892727     238 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739012.893826     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739012.894854     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739012.895985     238 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739012.897988     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739012.898819     238 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739012.903320     238 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739012.907277     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739012.908300     238 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739012.911771     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739012.913336     238 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739012.922838     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739012.924362     238 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739012.926993     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739012.929932     238 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739012.935089     238 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739012.936047     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739012.939030     238 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739012.949168     238 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739012.951820     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739012.958279     238 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739012.960025     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739012.977371     238 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739012.983527     238 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739012.986756     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739012.987370     238 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739012.990051     238 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739012.991573     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739012.992789     238 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739012.995730     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739012.996450     238 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739012.998721     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739012.999313     238 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739013.000682     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739013.001599     238 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739013.002999     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739013.003719     238 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739013.007355     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739013.008324     238 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739013.012904     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739013.014246     238 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739013.017507     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739013.019316     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739013.020597     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739013.023129     238 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739013.024981     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739013.026059     238 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739013.029744     238 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739013.039913     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739013.040686     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739013.041539     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739013.043126     238 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739013.046477     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739013.048758     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739013.050011     238 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739013.054047     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739013.079324     238 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739013.099157     238 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739013.099836     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739013.100503     238 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739013.101633     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739013.102231     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739013.102865     238 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739013.103822     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739013.104285     238 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739013.105344     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739013.106049     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739013.106581     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739013.107687     238 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739013.109347     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739013.110750     238 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739013.111701     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739013.112592     238 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739013.113915     238 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739013.116153     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739013.117391     238 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739013.118690     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739013.119984     238 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739013.121334     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739013.122329     238 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775739013
# HOLDOUT EMB: 344/400
# HOLDOUT EMB: 348/400
# HOLDOUT EMB: 352/400
# HOLDOUT EMB: 356/400
# HOLDOUT EMB: 360/400
# HOLDOUT EMB: 364/400
# HOLDOUT EMB: 368/400
# HOLDOUT EMB: 372/400
# HOLDOUT EMB: 376/400
# HOLDOUT EMB: 380/400
# HOLDOUT EMB: 384/400
# HOLDOUT EMB: 388/400
# HOLDOUT EMB: 392/400
# HOLDOUT EMB: 396/400
# HOLDOUT EMB: 400/400
# Centroides listos.

# %% [markdown]
# ## 4) Resultados en jugadores vistos

# %%
acc_top1 = top_k_accuracy_score(
    hold_labels, centroid_scores, k=1, labels=np.arange(len(centroid_players))
)
acc_top3 = top_k_accuracy_score(
    hold_labels,
    centroid_scores,
    k=min(3, len(centroid_players)),
    labels=np.arange(len(centroid_players)),
)
acc_top5 = top_k_accuracy_score(
    hold_labels,
    centroid_scores,
    k=min(5, len(centroid_players)),
    labels=np.arange(len(centroid_players)),
)

cm_known = confusion_matrix(
    hold_labels, centroid_pred, labels=np.arange(len(centroid_players))
)

report_dict = classification_report(
    hold_labels,
    centroid_pred,
    labels=np.arange(len(centroid_players)),
    target_names=centroid_players,
    output_dict=True,
    zero_division=0,
)
report_df = pd.DataFrame(report_dict).T

per_player = []
for idx, player in enumerate(centroid_players):
    support = int(cm_known[idx].sum())
    correct = int(cm_known[idx, idx])
    recall = (correct / support) if support > 0 else np.nan
    per_player.append(
        {
            "player": player,
            "elo": PLAYER_ELO.get(player, np.nan),
            "support": support,
            "correct": correct,
            "recall": recall,
        }
    )
per_player_eval_df = pd.DataFrame(per_player).sort_values("elo")

knn_k = min(7, max(1, len(TRAIN_SAMPLES) // max(len(centroid_players), 1)))
knn = KNeighborsClassifier(n_neighbors=knn_k, weights="distance", metric="euclidean")
knn.fit(train_embeddings, train_labels)
knn_pred = knn.predict(hold_embeddings)
knn_acc = accuracy_score(hold_labels, knn_pred)

print("=" * 80)
print("RENDIMIENTO HOLD-OUT (jugadores vistos)")
print("=" * 80)
print(f"Top-1 centroid: {acc_top1:.2%}")
print(f"Top-3 centroid: {acc_top3:.2%}")
print(f"Top-5 centroid: {acc_top5:.2%}")
print(f"kNN accuracy (k={knn_k}): {knn_acc:.2%}")
print(f"Partidas evaluadas: {len(hold_labels)}")
print("=" * 80)

display(per_player_eval_df.assign(recall_pct=lambda df: df["recall"] * 100.0))
display(report_df.loc[[*centroid_players, "accuracy", "macro avg", "weighted avg"]])
# Out:
# ================================================================================
# RENDIMIENTO HOLD-OUT (jugadores vistos)
# ================================================================================
# Top-1 centroid: 32.25%
# Top-3 centroid: 63.50%
# Top-5 centroid: 79.75%
# kNN accuracy (k=7): 26.75%
# Partidas evaluadas: 400
# ================================================================================
#            player     elo  support  correct  recall  recall_pct
# 7        sabino31   755.0       40       22   0.550        55.0
# 9      ujjawal305   941.0       40       21   0.525        52.5
# 0  Arsibbalt-1991  1197.0       40        3   0.075         7.5
# 2      Migrant-is  1229.0       40       14   0.350        35.0
# 5          edulol  1460.0       40       10   0.250        25.0
# 8        shanis34  1653.0       40       13   0.325        32.5
# 4      V2ethereum  1889.0       40        5   0.125        12.5
# 3          RRusso  1899.0       40       13   0.325        32.5
# 6        giliazov  2006.0       40       21   0.525        52.5
# 1         Edssoto  2280.0       40        7   0.175        17.5
#                 precision  recall  f1-score   support
# Arsibbalt-1991   0.157895  0.0750  0.101695   40.0000
# Edssoto          0.175000  0.1750  0.175000   40.0000
# Migrant-is       0.259259  0.3500  0.297872   40.0000
# RRusso           0.333333  0.3250  0.329114   40.0000
# V2ethereum       0.200000  0.1250  0.153846   40.0000
# edulol           0.243902  0.2500  0.246914   40.0000
# giliazov         0.403846  0.5250  0.456522   40.0000
# sabino31         0.687500  0.5500  0.611111   40.0000
# shanis34         0.302326  0.3250  0.313253   40.0000
# ujjawal305       0.381818  0.5250  0.442105   40.0000
# accuracy         0.322500  0.3225  0.322500    0.3225
# macro avg        0.314488  0.3225  0.312743  400.0000
# weighted avg     0.314488  0.3225  0.312743  400.0000

# %%
ordered_players = sorted(
    centroid_players,
    key=lambda p: (
        np.isnan(PLAYER_ELO.get(p, np.nan)),
        PLAYER_ELO.get(p, np.inf),
        p.lower(),
    ),
)
order_idx = [centroid_players.index(p) for p in ordered_players]

cm_counts = cm_known[np.ix_(order_idx, order_idx)]
cm_sum = cm_counts.sum(axis=1, keepdims=True)
cm_pct = np.divide(cm_counts, np.maximum(cm_sum, 1), where=cm_sum > 0) * 100.0

labels_elo = []
for p in ordered_players:
    elo = PLAYER_ELO.get(p, np.nan)
    labels_elo.append(f"{p} ({int(round(elo)) if not np.isnan(elo) else '?'})")

fig, axes = plt.subplots(1, 2, figsize=(24, 9))
sns.heatmap(
    cm_counts,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=labels_elo,
    yticklabels=labels_elo,
    ax=axes[0],
)
axes[0].set_title("Confusion Matrix (counts) · orden ELO")
axes[0].set_xlabel("Predicción")
axes[0].set_ylabel("Jugador real")

sns.heatmap(
    cm_pct,
    annot=True,
    fmt=".1f",
    cmap="YlGnBu",
    xticklabels=labels_elo,
    yticklabels=labels_elo,
    ax=axes[1],
)
axes[1].set_title("Confusion Matrix (fila %) · orden ELO")
axes[1].set_xlabel("Predicción")
axes[1].set_ylabel("Jugador real")

for ax in axes:
    ax.tick_params(axis="x", rotation=45)
    ax.tick_params(axis="y", rotation=0)
plt.tight_layout()
plt.show()

topk_df = pd.DataFrame(
    {
        "metric": ["Top-1", "Top-3", "Top-5", f"kNN(k={knn_k})"],
        "accuracy": [acc_top1, acc_top3, acc_top5, knn_acc],
    }
)
plt.figure(figsize=(8, 4))
ax = sns.barplot(data=topk_df, x="metric", y="accuracy", palette="viridis")
ax.set_ylim(0, 1)
ax.set_title("Comparativa de accuracy")
for i, v in enumerate(topk_df["accuracy"]):
    ax.text(i, v + 0.02, f"{v:.1%}", ha="center", va="bottom")
plt.tight_layout()
plt.show()

plt.figure(figsize=(12, 5))
tmp = per_player_eval_df.copy()
tmp["recall_pct"] = tmp["recall"] * 100.0
ax = sns.barplot(data=tmp, x="player", y="recall_pct", palette="rocket")
ax.set_title("Recall por jugador (hold-out)")
ax.set_ylabel("Recall (%)")
ax.set_xlabel("")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_157/2202064753.py:60: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=topk_df, x="metric", y="accuracy", palette="viridis")
# /tmp/ipykernel_157/2202064753.py:71: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=tmp, x="player", y="recall_pct", palette="rocket")

# %%
own_dist = centroid_dists[np.arange(len(hold_labels)), hold_labels]
mask_other = np.ones_like(centroid_dists, dtype=bool)
mask_other[np.arange(len(hold_labels)), hold_labels] = False
nearest_other = np.min(np.where(mask_other, centroid_dists, np.inf), axis=1)

ratio = float(np.mean(own_dist) / np.mean(nearest_other))
margin = float(np.mean(nearest_other) - np.mean(own_dist))

print("ANÁLISIS DE DISTANCIAS · HOLD-OUT")
print("=" * 80)
print(f"Distancia media a centroide propio:            {np.mean(own_dist):.6f}")
print(f"Distancia media a centroide ajeno más cercano: {np.mean(nearest_other):.6f}")
print(f"Ratio own/other:                               {ratio:.4f}")
print(f"Margen efectivo (other-own):                   {margin:.6f}")
print("=" * 80)

fig, ax = plt.subplots(figsize=(10, 5))
ax.hist(own_dist, bins=30, alpha=0.75, label="a centroide propio", color="tab:green")
ax.hist(
    nearest_other,
    bins=30,
    alpha=0.70,
    label="a centroide ajeno más cercano",
    color="tab:red",
)
ax.set_title("Distribución de distancias en hold-out")
ax.set_xlabel("Distancia L2")
ax.set_ylabel("Frecuencia")
ax.legend()
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# ANÁLISIS DE DISTANCIAS · HOLD-OUT
# ================================================================================
# Distancia media a centroide propio:            0.036328
# Distancia media a centroide ajeno más cercano: 0.033289
# Ratio own/other:                               1.0913
# Margen efectivo (other-own):                   -0.003039
# ================================================================================

# %% [markdown]
# ## 5) Open-set: jugadores no vistos + similitud por ELO

# %%
def iter_zst_files(players_root: Path):
    for prefix_dir in sorted(players_root.iterdir()):
        if not prefix_dir.is_dir():
            continue
        for zst_path in prefix_dir.glob("*.pgn.zst"):
            yield zst_path


def select_unknown_players(
    known_players: List[str],
    max_players: int,
    candidate_pool: int,
    min_elo: int,
    max_elo: int,
    seed: int,
) -> pd.DataFrame:
    known_norm = {_norm_player(p) for p in known_players}
    candidates = []

    for zst_path in iter_zst_files(ZST_PLAYERS_DIR):
        player = zst_path.name[:-8]  # remove .pgn.zst
        if _norm_player(player) in known_norm:
            continue

        elo = extract_elo_from_zst(zst_path)
        if elo is None:
            continue
        if not (min_elo <= elo <= max_elo):
            continue

        candidates.append(
            {
                "player": player,
                "elo": int(elo),
                "zst_path": str(zst_path),
            }
        )

    if not candidates:
        raise RuntimeError("No se encontraron jugadores no vistos con ELO válido.")

    cand_df = pd.DataFrame(candidates)
    if len(cand_df) > candidate_pool:
        cand_df = cand_df.sample(candidate_pool, random_state=seed).reset_index(drop=True)

    bins = list(range(600, 3001, 200))
    cand_df["elo_bin"] = pd.cut(
        cand_df["elo"],
        bins=bins,
        labels=False,
        include_lowest=True,
    )

    selected_rows = []
    for elo_bin in sorted(cand_df["elo_bin"].dropna().unique()):
        if len(selected_rows) >= max_players:
            break
        group = cand_df[cand_df["elo_bin"] == elo_bin]
        selected_rows.append(group.sample(1, random_state=seed).iloc[0])

    if len(selected_rows) < max_players:
        used = {r["player"] for r in selected_rows}
        remainder = cand_df[~cand_df["player"].isin(used)]
        if not remainder.empty:
            extra = remainder.sample(
                min(max_players - len(selected_rows), len(remainder)),
                random_state=seed,
            )
            for _, row in extra.iterrows():
                selected_rows.append(row)

    return (
        pd.DataFrame(selected_rows)
        .drop(columns=["elo_bin"], errors="ignore")
        .sort_values("elo")
        .reset_index(drop=True)
    )


def infer_unknown_players(
    unknown_players_df: pd.DataFrame,
    games_per_player: int,
) -> pd.DataFrame:
    rows = []
    for _, row in unknown_players_df.iterrows():
        unknown_player = row["player"]
        unknown_elo = float(row["elo"])
        zst_path = Path(row["zst_path"])

        print(f"Procesando no-visto: {unknown_player} (ELO~{int(unknown_elo)})")
        games = read_player_games_from_zst(
            zst_path=zst_path,
            player_name=unknown_player,
            max_games=games_per_player,
        )
        print(f"  partidas útiles: {len(games)}")

        for game_idx, game, side in games:
            try:
                boards, heats = build_single_game_tensor(
                    game=game,
                    side=side,
                    sequence_len=CONFIG.sequence_len,
                    fullmove_start=CONFIG.fullmove_start,
                    fullmove_end=CONFIG.fullmove_end,
                    image_size=CONFIG.image_size,
                )
            except Exception:
                continue

            emb = embedding_model.predict(
                {"board_sequence": boards, "heat_sequence": heats},
                verbose=0,
            )[0]
            dists = np.linalg.norm(centroid_matrix - emb[None, :], axis=1)
            order = np.argsort(dists)

            top1_idx = int(order[0])
            top2_idx = int(order[1]) if len(order) > 1 else int(order[0])
            top1_player = centroid_players[top1_idx]
            top1_dist = float(dists[top1_idx])
            top2_dist = float(dists[top2_idx])
            margin = float(top2_dist - top1_dist)

            rows.append(
                {
                    "unknown_player": unknown_player,
                    "unknown_elo": unknown_elo,
                    "game_index": int(game_idx),
                    "side": side,
                    "pred_player_top1": top1_player,
                    "pred_elo_top1": PLAYER_ELO.get(top1_player, np.nan),
                    "top1_distance": top1_dist,
                    "top2_distance": top2_dist,
                    "top12_margin": margin,
                }
            )

    if not rows:
        raise RuntimeError("No se pudieron generar predicciones para jugadores no vistos.")
    return pd.DataFrame(rows)


unknown_players_df = select_unknown_players(
    known_players=SELECTED_PLAYERS,
    max_players=CONFIG.unknown_players_to_test,
    candidate_pool=CONFIG.unknown_candidate_pool,
    min_elo=CONFIG.unknown_min_elo,
    max_elo=CONFIG.unknown_max_elo,
    seed=SEED,
)
display(unknown_players_df)

unknown_predictions_df = infer_unknown_players(
    unknown_players_df=unknown_players_df,
    games_per_player=CONFIG.unknown_games_per_player,
)
unknown_predictions_df["elo_abs_error"] = (
    unknown_predictions_df["pred_elo_top1"] - unknown_predictions_df["unknown_elo"]
).abs()
display(unknown_predictions_df.head(30))
print(f"Predicciones no-vistos: {len(unknown_predictions_df)}")
# Out:
#              player   elo                                      zst_path
# 0       kostic34rus   942      /pgn_data/players/ko/kostic34rus.pgn.zst
# 1        SIRKRIFICE  1079       /pgn_data/players/si/SIRKRIFICE.pgn.zst
# 2         vt-oliver  1326        /pgn_data/players/vt/vt-oliver.pgn.zst
# 3             RFRbm  1465            /pgn_data/players/rf/RFRbm.pgn.zst
239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741285.211843     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741285.212250     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741285.212901     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741285.213952     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741285.215120     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741285.215889     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741285.217011     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741285.219538     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741285.220832     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741285.221394     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741285.227480     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741285.228279     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741285.228912     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741285.229496     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741285.230012     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741285.230841     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741285.231471     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741285.232086     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741285.233680     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741285.234378     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741285.235210     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741285.236220     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741285.236904     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741285.237615     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741285.238536     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741285.239746     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741285.241132     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741285.801138     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741285.801664     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741285.802261     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741285.802938     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741285.803674     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741285.804686     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741285.805591     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741285.807043     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741285.807690     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741285.808495     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741285.809523     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741285.810343     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741285.810935     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741285.811932     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741285.812827     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741285.813735     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741285.815075     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741286.339602     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741286.340289     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741286.340888     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741286.341614     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741286.342482     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741286.343320     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741286.343829     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741286.344637     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741286.345618     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741286.346182     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741286.346705     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741286.347209     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741286.347808     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741286.348550     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741286.349293     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741286.350591     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741286.352343     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741286.925269     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741286.925947     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741286.926714     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741286.927134     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741286.927661     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741286.928466     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741286.929440     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741286.929939     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741286.930525     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741286.931086     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741286.932181     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741286.933403     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741286.933988     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741286.934656     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741286.935424     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741286.936686     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741286.938309     239 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741287.461609     238 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741287.462432     238 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741287.463727     238 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741287.464364     238 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741287.465253     238 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741287.466199     238 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741287.466724     238 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741287.467451     238 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741287.468476     238 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741287.469196     238 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741287.470049     238 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741287.471247     238 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741287.472030     238 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741287.472572     238 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741287.473361     238 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741287.474700     238 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741287.476788     238 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# Procesando no-visto: SIRKRIFICE (ELO~1079)
#   partidas útiles: 8
# W0000 00:00:1775741288.041733     241 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741288.042550     241 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741288.043434     241 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741288.044047     241 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741288.044810     241 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741288.045376     241 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741288.046315     241 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741288.047591     241 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741288.048377     241 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741288.049001     241 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741288.049840     241 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741288.050859     241 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741288.051539     241 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741288.052348     241 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741288.053698     241 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741288.054848     241 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741288.057439     241 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741288.544888     240 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741288.545390     240 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741288.545863     240 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741288.546374     240 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741288.547230     240 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741288.548188     240 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741288.548790     240 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741288.549461     240 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741288.550055     240 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741288.550941     240 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741288.552187     240 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741288.553649     240 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741288.554108     240 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741288.554650     240 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741288.555345     240 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741288.556163     240 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741288.558464     240 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741289.107238     240 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741289.107696     240 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741289.108157     240 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741289.108788     240 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741289.109572     240 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741289.110263     240 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741289.110797     240 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741289.112069     240 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741289.112986     240 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741289.113712     240 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741289.114735     240 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741289.115739     240 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741289.116427     240 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741289.116964     240 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741289.117674     240 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741289.118287     240 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1775741289.120388     240 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# Procesando no-visto: vt-oliver (ELO~1326)
#   partidas útiles: 8
# Procesando no-visto: RFRbm (ELO~1465)
#   partidas útiles: 8
# Procesando no-visto: Davidcmejias (ELO~1532)
#   partidas útiles: 8
# Procesando no-visto: IOH_HIRO_AL (ELO~1649)
#   partidas útiles: 8
# Procesando no-visto: srmusawi (ELO~1660)
#   partidas útiles: 8
# Procesando no-visto: S1966Ilshat1966 (ELO~1808)
#   partidas útiles: 8
# Procesando no-visto: rabbi2026 (ELO~1820)
#   partidas útiles: 8
# Procesando no-visto: MorganKane (ELO~2023)
#   partidas útiles: 8
# Procesando no-visto: kadrimatoshii (ELO~2150)
#   partidas útiles: 8
# Procesando no-visto: gmtofri (ELO~2285)
#   partidas útiles: 8
#    unknown_player  unknown_elo  game_index   side pred_player_top1  \
# 0     kostic34rus        942.0           1  black       Migrant-is
# 1     kostic34rus        942.0           2  white       Migrant-is
# 2     kostic34rus        942.0           3  black       ujjawal305
# 3     kostic34rus        942.0           4  white           RRusso
# 4     kostic34rus        942.0           5  black           RRusso
# 5     kostic34rus        942.0           6  white       Migrant-is
# 6     kostic34rus        942.0           7  black           edulol
# 7     kostic34rus        942.0           8  black       Migrant-is
# 8      SIRKRIFICE       1079.0           1  white   Arsibbalt-1991
# 9      SIRKRIFICE       1079.0           2  white       Migrant-is
# 10     SIRKRIFICE       1079.0           3  white       Migrant-is
# 11     SIRKRIFICE       1079.0           4  black         sabino31
# 12     SIRKRIFICE       1079.0           5  black           edulol
# 13     SIRKRIFICE       1079.0           6  black   Arsibbalt-1991
# 14     SIRKRIFICE       1079.0           7  black   Arsibbalt-1991
# 15     SIRKRIFICE       1079.0           8  black         sabino31
# 16      vt-oliver       1326.0           1  black          Edssoto
# 17      vt-oliver       1326.0           2  black       ujjawal305
# 18      vt-oliver       1326.0           3  black          Edssoto
# 19      vt-oliver       1326.0           4  white       Migrant-is
# 20      vt-oliver       1326.0           5  black       Migrant-is
# 21      vt-oliver       1326.0           6  white           RRusso
# 22      vt-oliver       1326.0           7  black       ujjawal305
# 23      vt-oliver       1326.0           8  black         giliazov
# 24          RFRbm       1465.0           1  black           RRusso
# 25          RFRbm       1465.0           2  white         sabino31
# 26          RFRbm       1465.0           3  black         sabino31
# 27          RFRbm       1465.0           4  white         sabino31
# 28          RFRbm       1465.0           5  black           RRusso
# 29          RFRbm       1465.0           6  black       V2ethereum
#
#     pred_elo_top1  top1_distance  top2_distance  top12_margin  elo_abs_error
# 0          1229.0       0.036866       0.039008      0.002142          287.0
# 1          1229.0       0.032688       0.036626      0.003938          287.0
# 2           941.0       0.033626       0.034245      0.000619            1.0
# 3          1899.0       0.029353       0.029791      0.000438          957.0
# 4          1899.0       0.032655       0.033562      0.000907          957.0
# 5          1229.0       0.037167       0.039289      0.002122          287.0
# 6          1460.0       0.029214       0.031932      0.002718          518.0
# 7          1229.0       0.037510       0.041539      0.004029          287.0
# 8          1197.0       0.025582       0.025743      0.000161          118.0
# 9          1229.0       0.034319       0.039025      0.004706          150.0
# 10         1229.0       0.028686       0.031163      0.002477          150.0
# 11          755.0       0.032614       0.040215      0.007601          324.0
# 12         1460.0       0.026729       0.028723      0.001994          381.0
# 13         1197.0       0.033409       0.033507      0.000098          118.0
# 14         1197.0       0.029164       0.029268      0.000104          118.0
# 15          755.0       0.033935       0.034490      0.000555          324.0
# 16         2280.0       0.037874       0.038011      0.000137          954.0
# 17          941.0       0.030670       0.033144      0.002474          385.0
# 18         2280.0       0.043556       0.043994      0.000439          954.0
# 19         1229.0       0.023987       0.026781      0.002794           97.0
# 20         1229.0       0.025140       0.025541      0.000401           97.0
# 21         1899.0       0.026337       0.030314      0.003978          573.0
# 22          941.0       0.035779       0.036200      0.000421          385.0
# 23         2006.0       0.038662       0.039659      0.000997          680.0
# 24         1899.0       0.028241       0.031341      0.003099          434.0
# 25          755.0       0.032244       0.051194      0.018950          710.0
# 26          755.0       0.031336       0.036892      0.005556          710.0
# 27          755.0       0.026952       0.039071      0.012118          710.0
# 28         1899.0       0.043216       0.045835      0.002619          434.0
# 29         1889.0       0.023928       0.024405      0.000478          424.0
# Predicciones no-vistos: 96

# %%
def _mode_first(series: pd.Series):
    m = series.mode(dropna=True)
    return m.iloc[0] if not m.empty else np.nan


unknown_summary_df = (
    unknown_predictions_df.groupby(["unknown_player", "unknown_elo"], as_index=False)
    .agg(
        games_evaluated=("game_index", "count"),
        pred_player_mode=("pred_player_top1", _mode_first),
        pred_elo_mean=("pred_elo_top1", "mean"),
        top1_dist_mean=("top1_distance", "mean"),
        top12_margin_mean=("top12_margin", "mean"),
    )
    .sort_values("unknown_elo")
    .reset_index(drop=True)
)
unknown_summary_df["elo_abs_error"] = (
    unknown_summary_df["pred_elo_mean"] - unknown_summary_df["unknown_elo"]
).abs()

known_min_dist = np.min(centroid_dists, axis=1)
unknown_min_dist = unknown_predictions_df["top1_distance"].values
ood_threshold = float(np.quantile(known_min_dist, CONFIG.ood_quantile))

known_false_reject_rate = float(np.mean(known_min_dist > ood_threshold))
unknown_reject_rate = float(np.mean(unknown_min_dist > ood_threshold))

elo_eval_df = unknown_summary_df.dropna(subset=["pred_elo_mean", "unknown_elo"]).copy()
elo_mae = float(np.mean(np.abs(elo_eval_df["pred_elo_mean"] - elo_eval_df["unknown_elo"])))
elo_corr = (
    float(np.corrcoef(elo_eval_df["unknown_elo"], elo_eval_df["pred_elo_mean"])[0, 1])
    if len(elo_eval_df) >= 2
    else np.nan
)

print("=" * 80)
print("OPEN-SET / JUGADORES NO VISTOS")
print("=" * 80)
print(f"Jugadores no vistos evaluados: {unknown_summary_df.shape[0]}")
print(f"Partidas no vistas evaluadas: {unknown_predictions_df.shape[0]}")
print(f"MAE ELO (pred_top1 vs elo real): {elo_mae:.1f}")
print(f"Correlación ELO real vs ELO predicho: {elo_corr:.3f}")
print(f"Umbral OOD (q={CONFIG.ood_quantile:.0%} conocidos): {ood_threshold:.4f}")
print(f"False reject conocidos: {known_false_reject_rate:.2%}")
print(f"Reject no-vistos: {unknown_reject_rate:.2%}")
print("=" * 80)
display(unknown_summary_df)

fig, axes = plt.subplots(1, 2, figsize=(16, 6))

axes[0].scatter(
    elo_eval_df["unknown_elo"],
    elo_eval_df["pred_elo_mean"],
    alpha=0.8,
    s=80,
    color="tab:blue",
)
if not elo_eval_df.empty:
    lo = float(min(elo_eval_df["unknown_elo"].min(), elo_eval_df["pred_elo_mean"].min()))
    hi = float(max(elo_eval_df["unknown_elo"].max(), elo_eval_df["pred_elo_mean"].max()))
    axes[0].plot([lo, hi], [lo, hi], "k--", linewidth=1)
axes[0].set_title("ELO no-visto vs ELO del jugador más parecido")
axes[0].set_xlabel("ELO real (no-visto)")
axes[0].set_ylabel("ELO medio predicho (top-1)")
axes[0].grid(True, alpha=0.3)

axes[1].hist(known_min_dist, bins=35, alpha=0.65, label="conocidos (hold-out)", color="tab:green")
axes[1].hist(unknown_min_dist, bins=35, alpha=0.65, label="no-vistos", color="tab:orange")
axes[1].axvline(ood_threshold, color="tab:red", linestyle="--", linewidth=2, label="umbral OOD")
axes[1].set_title("Distribución de distancia mínima al centroide")
axes[1].set_xlabel("Distancia L2 mínima")
axes[1].set_ylabel("Frecuencia")
axes[1].legend()
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

plt.figure(figsize=(12, 5))
err_df = unknown_summary_df.sort_values("unknown_elo")
ax = sns.barplot(data=err_df, x="unknown_player", y="elo_abs_error", palette="magma")
ax.set_title("Error absoluto de ELO por jugador no-visto")
ax.set_xlabel("")
ax.set_ylabel("|ELO real - ELO predicho|")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()
# Out:
# ================================================================================
# OPEN-SET / JUGADORES NO VISTOS
# ================================================================================
# Jugadores no vistos evaluados: 12
# Partidas no vistas evaluadas: 96
# MAE ELO (pred_top1 vs elo real): 173.6
# Correlación ELO real vs ELO predicho: 0.830
# Umbral OOD (q=95% conocidos): 0.0420
# False reject conocidos: 5.00%
# Reject no-vistos: 5.21%
# ================================================================================
#      unknown_player  unknown_elo  games_evaluated pred_player_mode  \
# 0       kostic34rus        942.0                8       Migrant-is
# 1        SIRKRIFICE       1079.0                8   Arsibbalt-1991
# 2         vt-oliver       1326.0                8          Edssoto
# 3             RFRbm       1465.0                8         sabino31
# 4      Davidcmejias       1532.0                8       Migrant-is
# 5       IOH_HIRO_AL       1649.0                8         giliazov
# 6          srmusawi       1660.0                8           edulol
# 7   S1966Ilshat1966       1808.0                8         giliazov
# 8         rabbi2026       1820.0                8          Edssoto
# 9        MorganKane       2023.0                8          Edssoto
# 10    kadrimatoshii       2150.0                8          Edssoto
# 11          gmtofri       2285.0                8         giliazov
#
#     pred_elo_mean  top1_dist_mean  top12_margin_mean  elo_abs_error
# 0        1389.375        0.033635           0.002114        447.375
# 1        1127.375        0.030555           0.002212         48.375
# 2        1600.625        0.032751           0.001455        274.625
# 3        1427.250        0.030690           0.007219         37.750
# 4        1589.000        0.030956           0.001756         57.000
# 5        1726.375        0.033759           0.009313         77.375
# 6        1397.250        0.032453           0.002191        262.750
# 7        1948.750        0.032774           0.003526        140.750
# 8        1974.375        0.030330           0.002215        154.375
# 9        1833.000        0.031483           0.002302        190.000
# 10       2150.500        0.030636           0.002430          0.500
# 11       1892.500        0.036889           0.004203        392.500
# /tmp/ipykernel_157/1667144621.py:82: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=err_df, x="unknown_player", y="elo_abs_error", palette="magma")

# %%
history_df = pd.read_csv(HISTORY_CSV_PATH) if HISTORY_CSV_PATH.exists() else pd.DataFrame()
if not history_df.empty:
    if "epoch" not in history_df.columns:
        history_df = history_df.reset_index().rename(columns={"index": "epoch"})

    fig, axes = plt.subplots(1, 2, figsize=(14, 5))
    axes[0].plot(history_df["epoch"], history_df.get("loss", np.nan), label="train loss")
    if "val_loss" in history_df.columns:
        axes[0].plot(history_df["epoch"], history_df["val_loss"], label="val loss")
    axes[0].set_title("Histórico de loss")
    axes[0].set_xlabel("Epoch")
    axes[0].grid(True, alpha=0.3)
    axes[0].legend()

    if "triplet_loss" in history_df.columns:
        axes[1].plot(history_df["epoch"], history_df["triplet_loss"], label="train triplet")
    if "val_triplet_loss" in history_df.columns:
        axes[1].plot(history_df["epoch"], history_df["val_triplet_loss"], label="val triplet")
    if "hard_gap" in history_df.columns:
        axes[1].plot(history_df["epoch"], history_df["hard_gap"], label="train hard_gap")
    if "val_hard_gap" in history_df.columns:
        axes[1].plot(history_df["epoch"], history_df["val_hard_gap"], label="val hard_gap")
    axes[1].set_title("Triplet / hard-gap")
    axes[1].set_xlabel("Epoch")
    axes[1].grid(True, alpha=0.3)
    axes[1].legend()
    plt.tight_layout()
    plt.show()


def pct(x: float) -> str:
    return f"{x:.2%}"


print("RESUMEN EJECUTIVO")
print("=" * 80)
print(f"Top-1 hold-out: {pct(acc_top1)}")
print(f"Top-3 hold-out: {pct(acc_top3)}")
print(f"Top-5 hold-out: {pct(acc_top5)}")
print(f"kNN hold-out:   {pct(knn_acc)}")
print(f"False reject conocidos (OOD): {pct(known_false_reject_rate)}")
print(f"Reject no-vistos (OOD):       {pct(unknown_reject_rate)}")
print(f"MAE ELO no-vistos: {elo_mae:.1f} puntos")
if not np.isnan(elo_corr):
    print(f"Correlación ELO real/predicho: {elo_corr:.3f}")
else:
    print("Correlación ELO: no disponible")
print("=" * 80)
# Out:
# RESUMEN EJECUTIVO
# ================================================================================
# Top-1 hold-out: 32.25%
# Top-3 hold-out: 63.50%
# Top-5 hold-out: 79.75%
# kNN hold-out:   26.75%
# False reject conocidos (OOD): 5.00%
# Reject no-vistos (OOD):       5.21%
# MAE ELO no-vistos: 173.6 puntos
# Correlación ELO real/predicho: 0.830
# ================================================================================

# %%
def predict_player_from_pgn(
    pgn_path: Path,
    game_index: int = 1,
    side: str = "white",
    top_k: int = 5,
) -> pd.DataFrame:
    if not pgn_path.exists():
        raise FileNotFoundError(f"No existe {pgn_path}")
    if pgn_path.is_dir():
        raise ValueError("pgn_path debe ser un archivo .pgn, no un directorio.")

    with open(pgn_path, "r", encoding="utf-8", errors="replace") as f:
        game = None
        for _ in range(game_index):
            game = chess.pgn.read_game(f)
            if game is None:
                raise RuntimeError(f"No existe game_index={game_index} en {pgn_path}")

    boards, heats = build_single_game_tensor(
        game=game,
        side=side,
        sequence_len=CONFIG.sequence_len,
        fullmove_start=CONFIG.fullmove_start,
        fullmove_end=CONFIG.fullmove_end,
        image_size=CONFIG.image_size,
    )
    emb = embedding_model.predict(
        {"board_sequence": boards, "heat_sequence": heats},
        verbose=0,
    )[0]

    dists = np.linalg.norm(centroid_matrix - emb[None, :], axis=1)
    order = np.argsort(dists)[: max(1, top_k)]

    rows = []
    for rank_idx, idx in enumerate(order, start=1):
        player = centroid_players[idx]
        rows.append(
            {
                "rank": rank_idx,
                "player": player,
                "player_elo": PLAYER_ELO.get(player, np.nan),
                "distance": float(dists[idx]),
            }
        )
    return pd.DataFrame(rows)


print("Helper listo: predict_player_from_pgn(...)")
example_player = TRAINED_PLAYERS[0] if TRAINED_PLAYERS else "<player>"
example_pgn = PGN_TESTS_DIR / f"{example_player}.pgn"
print("Ejemplo:")
print(
    f"predict_player_from_pgn(Path(r'{example_pgn}'), game_index=1, side='white', top_k=5)"
)
# Out:
# Helper listo: predict_player_from_pgn(...)
# Ejemplo:
# predict_player_from_pgn(Path(r'/workspace/code/labs/notebooks/output/events/compressed_120/pgn_tests/Arsibbalt-1991.pgn'), game_index=1, side='white', top_k=5)

# %%
predict_player_from_pgn(Path(r'/workspace/code/labs/notebooks/output/events/compressed_120/pgn_tests/Arsibbalt-1991.pgn'), game_index=1, side='white', top_k=5)
# Out:
#    rank          player  player_elo  distance
# 0     1        shanis34      1653.0  0.022254
# 1     2      Migrant-is      1229.0  0.027634
# 2     3          edulol      1460.0  0.027635
# 3     4      V2ethereum      1889.0  0.028039
# 4     5  Arsibbalt-1991      1197.0  0.028131
