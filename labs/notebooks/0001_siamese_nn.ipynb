# %%
#SETUP
# %pip install tensorflow
import matplotlib.pyplot as plt
import numpy as np
import os
import random
import tensorflow as tf
from pathlib import Path
from keras import applications
from keras import layers
from keras import losses
from keras import ops
from keras import optimizers
from keras import metrics
from keras import Model
from keras.applications import resnet


target_shape = (200, 200)
# Out:
# Requirement already satisfied: tensorflow in /home/andrewyernau/dev/jupyter/venv/lib/python3.12/site-packages (2.20.0)
# Requirement already satisfied: absl-py>=1.0.0 in /home/andrewyernau/dev/jupyter/venv/lib/python3.12/site-packages (from tensorflow) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in /home/andrewyernau/dev/jupyter/venv/lib/python3.12/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /home/andrewyernau/dev/jupyter/venv/lib/python3.12/site-packages (from tensorflow) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /home/andrewyernau/dev/jupyter/venv/lib/python3.12/site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /home/andrewyernau/dev/jupyter/venv/lib/python3.12/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/andrewyernau/dev/jupyter/venv/lib/python3.12/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /home/andrewyernau/dev/jupyter/venv/lib/python3.12/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /home/andrewyernau/dev/jupyter/venv/lib/python3.12/site-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf>=5.28.0 in /home/andrewyernau/dev/jupyter/venv/lib/python3.12/site-packages (from tensorflow) (6.33.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/andrewyernau/dev/jupyter/venv/lib/python3.12/site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: setuptools in /home/andrewyernau/dev/jupyter/venv/lib/python3.12/site-packages (from tensorflow) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in /home/andrewyernau/dev/jupyter/venv/lib/python3.12/site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/andrewyernau/dev/jupyter/venv/lib/python3.12/site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /home/andrewyernau/dev/jupyter/venv/lib/python3.12/site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /home/andrewyernau/dev/jupyter/venv/lib/python3.12/site-packages (from tensorflow) (1.17.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/andrewyernau/dev/jupyter/venv/lib/python3.12/site-packages (from tensorflow) (1.75.1)
# Requirement already satisfied: tensorboard~=2.20.0 in /home/andrewyernau/dev/jupyter/venv/lib/python3.12/site-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in /home/andrewyernau/dev/jupyter/venv/lib/python3.12/site-packages (from tensorflow) (3.11.3)
# Requirement already satisfied: numpy>=1.26.0 in /home/andrewyernau/dev/jupyter/venv/lib/python3.12/site-packages (from tensorflow) (2.2.6)
# Requirement already satisfied: h5py>=3.11.0 in /home/andrewyernau/dev/jupyter/venv/lib/python3.12/site-packages (from tensorflow) (3.15.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /home/andrewyernau/dev/jupyter/venv/lib/python3.12/site-packages (from tensorflow) (0.5.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/andrewyernau/dev/jupyter/venv/lib/python3.12/site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /home/andrewyernau/dev/jupyter/venv/lib/python3.12/site-packages (from keras>=3.10.0->tensorflow) (14.2.0)
# Requirement already satisfied: namex in /home/andrewyernau/dev/jupyter/venv/lib/python3.12/site-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /home/andrewyernau/dev/jupyter/venv/lib/python3.12/site-packages (from keras>=3.10.0->tensorflow) (0.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/andrewyernau/dev/jupyter/venv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /home/andrewyernau/dev/jupyter/venv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/andrewyernau/dev/jupyter/venv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/andrewyernau/dev/jupyter/venv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2025.8.3)
# Requirement already satisfied: markdown>=2.6.8 in /home/andrewyernau/dev/jupyter/venv/lib/python3.12/site-packages (from tensorboard~=2.20.0->tensorflow) (3.9)
# Requirement already satisfied: pillow in /home/andrewyernau/dev/jupyter/venv/lib/python3.12/site-packages (from tensorboard~=2.20.0->tensorflow) (11.3.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/andrewyernau/dev/jupyter/venv/lib/python3.12/site-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/andrewyernau/dev/jupyter/venv/lib/python3.12/site-packages (from tensorboard~=2.20.0->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/andrewyernau/dev/jupyter/venv/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/andrewyernau/dev/jupyter/venv/lib/python3.12/site-packages (from rich->keras>=3.10.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/andrewyernau/dev/jupyter/venv/lib/python3.12/site-packages (from rich->keras>=3.10.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /home/andrewyernau/dev/jupyter/venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# 2025-10-17 16:11:22.077626: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
from pathlib import Path
import sys

# Directorio raíz (labs)
root = Path("/home/andrewyernau/dev/jupyter/labs")

parse_file = root / "parse_games_to_images.py"
if not parse_file.exists():
    raise FileNotFoundError(f"No se encontró {parse_file}")
if str(root) not in sys.path:
    sys.path.append(str(root))
from parse_games_to_images import main as parse_games

# %%
def pgn_to_png(pgn_subdir: str, output_subdir: str, start_move=15, end_move=23, compression=4):
    base_dir = Path(".")
    parse_games(
        pgn_dir=base_dir / "dataset" / pgn_subdir,
        output_dir=base_dir / "output" / output_subdir,
        start_move=start_move,
        end_move=end_move,
        compression_factor=compression
    )

# %%
pgn_to_png("testpgns", "left")
pgn_to_png("testpgnsright", "right")
# Out:
# ======================================================================
# PROCESANDO PARTIDAS DE AJEDREZ
# ======================================================================
# Directorio PGN: dataset/testpgns
# Directorio salida: output/left
# Rango de movimientos: 15-23
# Factor de compresión: 4x
# Archivos PGN encontrados: 10
# ======================================================================
#
#
# 📁 Procesando: Antunesl.pgn
#    ------------------------------------------------------------------
# ✓ Antunesl_game01.png (100x100)
# ✓ Antunesl_game02.png (100x100)
# ✓ Antunesl_game03.png (100x100)
# ✓ Antunesl_game04.png (100x100)
# ✓ Antunesl_game05.png (100x100)
# ✓ Antunesl_game06.png (100x100)
# ✓ Antunesl_game07.png (100x100)
# ✓ Antunesl_game08.png (100x100)
# ✓ Antunesl_game09.png (100x100)
# ✓ Antunesl_game10.png (100x100)
# ✓ Antunesl_game11.png (100x100)
# ✓ Antunesl_game12.png (100x100)
# ✓ Antunesl_game13.png (100x100)
#    ------------------------------------------------------------------
#    Partidas procesadas: 13
#
# 📁 Procesando: Howell.pgn
#    ------------------------------------------------------------------
# ✓ Howell_game01.png (100x100)
# ✓ Howell_game02.png (100x100)
# ✓ Howell_game03.png (100x100)
# ✓ Howell_game04.png (100x100)
# ✓ Howell_game05.png (100x100)
# ✓ Howell_game06.png (100x100)
# ✓ Howell_game07.png (100x100)
# ✓ Howell_game08.png (100x100)
# ✓ Howell_game09.png (100x100)
# ✓ Howell_game10.png (100x100)
# ✓ Howell_game11.png (100x100)
# ✓ Howell_game12.png (100x100)
# ✓ Howell_game13.png (100x100)
#    ------------------------------------------------------------------
#    Partidas procesadas: 13
#
# 📁 Procesando: Izsak.pgn
#    ------------------------------------------------------------------
# ✓ Izsak_game01.png (100x100)
# ✓ Izsak_game02.png (100x100)
# ✓ Izsak_game03.png (100x100)
# ✓ Izsak_game04.png (100x100)
# ✓ Izsak_game05.png (100x100)
# ✓ Izsak_game06.png (100x100)
# ✓ Izsak_game07.png (100x100)
# ✓ Izsak_game08.png (100x100)
# ✓ Izsak_game09.png (100x100)
# ✓ Izsak_game10.png (100x100)
#    ------------------------------------------------------------------
#    Partidas procesadas: 10
#
# 📁 Procesando: Kantsler.pgn
#    ------------------------------------------------------------------
# ✓ Kantsler_game01.png (100x100)
# ✓ Kantsler_game02.png (100x100)
# ✓ Kantsler_game03.png (100x100)
# ✓ Kantsler_game04.png (100x100)
# ✓ Kantsler_game05.png (100x100)
# ✓ Kantsler_game06.png (100x100)
# ✓ Kantsler_game07.png (100x100)
# ✓ Kantsler_game08.png (100x100)
# ✓ Kantsler_game09.png (100x100)
# ✓ Kantsler_game10.png (100x100)
# ✓ Kantsler_game11.png (100x100)
#    ------------------------------------------------------------------
#    Partidas procesadas: 11
#
# 📁 Procesando: Magem.pgn
#    ------------------------------------------------------------------
# ✓ Magem_game01.png (100x100)
# ✓ Magem_game02.png (100x100)
# ✓ Magem_game03.png (100x100)
# ✓ Magem_game04.png (100x100)
# ✓ Magem_game05.png (100x100)
# ✓ Magem_game06.png (100x100)
# ✓ Magem_game07.png (100x100)
# ✓ Magem_game08.png (100x100)
# ✓ Magem_game09.png (100x100)
# ✓ Magem_game10.png (100x100)
# ✓ Magem_game11.png (100x100)
# ✓ Magem_game12.png (100x100)
# ✓ Magem_game13.png (100x100)
#    ------------------------------------------------------------------
#    Partidas procesadas: 13
#
# 📁 Procesando: Moroz.pgn
#    ------------------------------------------------------------------
# ✓ Moroz_game01.png (100x100)
# ✓ Moroz_game02.png (100x100)
# ✓ Moroz_game03.png (100x100)
# ✓ Moroz_game04.png (100x100)
# ✓ Moroz_game05.png (100x100)
# ✗ Moroz game 6: [CHESS_CNN] La partida tiene solo 0 movimientos, pero se solicitaron movimientos 15-23
# ✓ Moroz_game07.png (100x100)
# ✓ Moroz_game08.png (100x100)
# ✓ Moroz_game09.png (100x100)
# ✓ Moroz_game10.png (100x100)
# ✓ Moroz_game11.png (100x100)
# ✓ Moroz_game12.png (100x100)
#    ------------------------------------------------------------------
#    Partidas procesadas: 11
#
# 📁 Procesando: Narciso.pgn
#    ------------------------------------------------------------------
# ✓ Narciso_game01.png (100x100)
# ✓ Narciso_game02.png (100x100)
# ✓ Narciso_game03.png (100x100)
# ✓ Narciso_game04.png (100x100)
# ✓ Narciso_game05.png (100x100)
# ✓ Narciso_game06.png (100x100)
# ✓ Narciso_game07.png (100x100)
# ✓ Narciso_game08.png (100x100)
# ✓ Narciso_game09.png (100x100)
#    ------------------------------------------------------------------
#    Partidas procesadas: 9
#
# 📁 Procesando: Olafsson.pgn
#    ------------------------------------------------------------------
# ✓ Olafsson_game01.png (100x100)
# ✓ Olafsson_game02.png (100x100)
# ✓ Olafsson_game03.png (100x100)
# ✓ Olafsson_game04.png (100x100)
# ✓ Olafsson_game05.png (100x100)
# ✓ Olafsson_game06.png (100x100)
# ✓ Olafsson_game07.png (100x100)
# ✓ Olafsson_game08.png (100x100)
# ✓ Olafsson_game09.png (100x100)
# ✓ Olafsson_game10.png (100x100)
# ✓ Olafsson_game11.png (100x100)
# ✓ Olafsson_game12.png (100x100)
# ✓ Olafsson_game13.png (100x100)
#    ------------------------------------------------------------------
#    Partidas procesadas: 13
#
# 📁 Procesando: Saldano.pgn
#    ------------------------------------------------------------------
# ✓ Saldano_game01.png (100x100)
# ✓ Saldano_game02.png (100x100)
# ✓ Saldano_game03.png (100x100)
# ✓ Saldano_game04.png (100x100)
